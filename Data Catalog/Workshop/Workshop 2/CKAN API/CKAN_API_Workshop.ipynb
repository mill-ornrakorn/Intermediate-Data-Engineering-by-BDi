# %%
import pandas as pd
import pandas as np
import psycopg2
from psycopg2 import sql
import requests
import json
import pprint
import os
from ast import literal_eval

# %%
CKAN_URL = ''
API_KEY = ''

# %% [markdown]
# ## CKAN API Functions:

# %%
def ckan_create_organization(org_dict, ckan_url, api_key, upload_image=False):
    '''
        Create new organization in ckan
    '''
    body_json = json.dumps(org_dict)  #reformat
    req = requests.post(ckan_url+'/api/action/organization_create', headers={'User-Agent':"Magic Browser", 'Authorization':api_key, "Content-Type": "application/json"}, data=body_json)
    assert req.status_code == 200             #check the request status (ckan always replies with 200)
    response_dict = json.loads(req.text)      #check the actual response 'success' status
    assert response_dict['success'] is True

    print('----- org: ' + org_dict['name'] + ' created')
    return response_dict['result']

# %%
# def ckan_delete_organization(org_dict, ckan_url, api_key, upload_image=False):
#     '''
#         Create new organization in ckan
#         Input
#             org_dict : python dictionary which has {'key':'value'} ~ ckan org metadata
#             upload_image : specify whether to upload an image
#         *** Note that the org/group images need to be uploaded to /var/lib/ckan/default/storage/uploads/group

#     '''
#     body_json = json.dumps(org_dict)  #reformat
#     req = requests.post(ckan_url+'/api/action/organization_create', headers={'User-Agent':"Magic Browser", 'Authorization':api_key, "Content-Type": "application/json"}, data=body_json)
#     assert req.status_code == 200             #check the request status (ckan always replies with 200)
#     response_dict = json.loads(req.text)      #check the actual response 'success' status
#     assert response_dict['success'] is True

#     print('----- org: ' + org_dict['name'] + ' created')
#     return response_dict['result']

# %%
def ckan_create_user(user_dict, ckan_url, api_key, upload_image=False):
    '''
        Create new user in ckan
    '''
    body_json = json.dumps(user_dict)  #reformat
    req = requests.post(ckan_url+'/api/action/user_create', headers={'User-Agent':"Magic Browser", 'Authorization':api_key, "Content-Type": "application/json"}, data=body_json)
    print(req.text)
    assert req.status_code == 200             #check the request status (ckan always replies with 200)
    response_dict = json.loads(req.text)      #check the actual response 'success' status
    assert response_dict['success'] is True

    return response_dict['result']

# %%
def ckan_update_user(user_update_dict, ckan_url, api_key, upload_image=False):
    '''
        Update user in ckan
    '''
    print(user_update_dict)
    body_json = json.dumps(user_update_dict)  #reformat
    req = requests.post(ckan_url+'/api/action/user_update', headers={'User-Agent':"Magic Browser", 'Authorization':api_key, "Content-Type": "application/json"}, data=body_json)
    print(req.text)
    assert req.status_code == 200             #check the request status (ckan always replies with 200)
    response_dict = json.loads(req.text)      #check the actual response 'success' status
    assert response_dict['success'] is True

    return response_dict['result']

# %%
def ckan_delete_user(user_id_dict, ckan_url, api_key):
    '''
        Delete User in ckan
    '''
    body_json = json.dumps(user_id_dict)  #reformat
    req = requests.post(ckan_url+'/api/action/user_delete', headers={'User-Agent':"Magic Browser", 'Authorization':api_key, "Content-Type": "application/json"}, data=body_json)
    print(req.text)
    assert req.status_code == 200             #check the request status (ckan always replies with 200)
    response_dict = json.loads(req.text)      #check the actual response 'success' status
    assert response_dict['success'] is True

    return response_dict['result']

# %%
def ckan_assign_org_member(org_member_dict, ckan_url, api_key):
    '''
        Assign member to organization
    '''

# %% [markdown]
# ## Create Organizations:

# %%
df_org = pd.read_excel("depa_organizations.xlsx")

# %%
df_org
# Out:
#                                                org_id  \
# 0                       corporate-strategy-department
# 1                    office-administration-department
# 2                      policy-and-strategy-department
# 3                               smart-city-department
# 4               digital-industry-promotion-department
# 5       finanfe-and-central-administration-department
# 6                                       iot-institute
# 7                                                 dmd
# 8   organization-and-human-resources-management-de...
# 9   digital-platform-and-service-promotion-department
# 10                                  startup-institute
# 11  promotion-and-support-for-the-development-of-m...
# 12     industrial-and-business-development-department
# 13                                                dqs
# 14                                               gbdi
#
#                                              org_name  \
# 0                                   ฝ่ายกลยุทธ์องค์กร
# 1                                ฝ่ายอำนวยการสำนักงาน
# 2                              ฝ่ายนโยบายและยุทศาสตร์
# 3                           ฝ่ายส่งเสริมเมืองอัจฉริยะ
# 4                       ฝ่ายส่งเสริมอุตสาหกรรมดิจิทัล
# 5                      ฝ่ายบริหารการคลังและบริหารกลาง
# 6                      สถาบันไอโอทีและนวัตกรรมดิจิทัล
# 7                ฝ่ายสงเสริมแพลตฟอร์มและบริการดิจิทัล
# 8                    ฝ่ายบริหารทรัพยากรองค์กรและบุคคล
# 9                ฝ่ายสงเสริมแพลตฟอร์มและบริการดิจิทัล
# 10              สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น
# 11    ฝ่ายส่งเสริมและสนับสนุนการพัฒนาการเกษตรสมัยใหม่
# 12  ฝ่ายส่งเสริมและสนับสนุนการพัฒนาอุตสาหกรรมและธุ...
# 13  ฝ่ายส่งเสริมและสนับสนุนการพัฒนาคุณภาพชีวิตและค...
# 14  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...
#
#                                           description
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   เป็นองค์กรหลักในการขับเคลื่อนการพัฒนาเทคโนโลยี...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น (Digital...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...

# %%
df_org_master = df_org.copy()

# %%
df_org_master.rename(columns = {"org_id":"name", "org_name": "title"},inplace = True)

# %%
df_org_master.to_json('org_master.json', force_ascii=False, orient='records')

# %%
with open('org_master.json', encoding="utf8") as readfile:
    org_master_dict =  json.load(readfile)
org_master_dict
# Out:
# [{'name': 'corporate-strategy-department',
#   'title': 'ฝ่ายกลยุทธ์องค์กร',
#   'description': None},
#  {'name': 'office-administration-department',
#   'title': 'ฝ่ายอำนวยการสำนักงาน',
#   'description': None},
#  {'name': 'policy-and-strategy-department',
#   'title': 'ฝ่ายนโยบายและยุทศาสตร์',
#   'description': None},
#  {'name': 'smart-city-department',
#   'title': 'ฝ่ายส่งเสริมเมืองอัจฉริยะ',
#   'description': None},
#  {'name': 'digital-industry-promotion-department',
#   'title': 'ฝ่ายส่งเสริมอุตสาหกรรมดิจิทัล',
#   'description': None},
#  {'name': 'finanfe-and-central-administration-department',
#   'title': 'ฝ่ายบริหารการคลังและบริหารกลาง',
#   'description': None},
#  {'name': 'iot-institute',
#   'title': 'สถาบันไอโอทีและนวัตกรรมดิจิทัล',
#   'description': 'เป็นองค์กรหลักในการขับเคลื่อนการพัฒนาเทคโนโลยี นวัตกรรม และอุตสาหกรรมดิจิทัล เพื่อมุ่งสู่การเป็น “ศูนย์กลางด้านการออกแบบและพัฒนาเทคโนโลยีและนวัตกรรมดิจิทัลขั้นสูงแห่งภูมิภาคอาเซียน (ASEAN Digital Hub)”'},
#  {'name': 'dmd',
#   'title': 'ฝ่ายสงเสริมแพลตฟอร์มและบริการดิจิทัล',
#   'description': None},
#  {'name': 'organization-and-human-resources-management-department',
#   'title': 'ฝ่ายบริหารทรัพยากรองค์กรและบุคคล',
#   'description': None},
#  {'name': 'digital-platform-and-service-promotion-department',
#   'title': 'ฝ่ายสงเสริมแพลตฟอร์มและบริการดิจิทัล',
#   'description': None},
#  {'name': 'startup-institute',
#   'title': 'สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น',
#   'description': 'สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น (Digital Startup Institute) เป็นสถาบันมุ่งเน้นความเป็นเลิศด้านการส่งเสริมวิสาหกิจเริ่มต้นครบวงจรภายใต้กำกับการดูแลของสำนักงานส่งเสริมเศรษฐกิจดิจิทัล ที่จัดตั้งขึ้นโดยมีวัตถุประสงค์เพื่อส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น (Digital Startups) ให้เป็นตัวจักรสำคัญในการพัฒนาและขับเคลื่อนประเทศสู่เศรษฐกิจดิจิทัล (Digital Economy) และเศรษฐกิจฐานผู้ประกอบการ (Entrepreneurial Economy) สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้นมุ่งเน้นการพัฒนาระบบนิเวศ (Ecosystem) ที่เหมาะสม เพื่อให้วิสาหกิจดิจิทัลเริ่มต้น สามารถเติบโตได้อย่างรวดเร็วและสามารถสร้างโอกาสทั้งในตลาดในประเทศและตลาดโลก ภารกิจที่สำคัญของสถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น ประกอบด้วย_x000D_\n_x000D_\nการพัฒนามาตรการส่งเสริมและสนับสนุน สิ่งอำนวยความสะดวก โครงสร้างพื้นฐาน และฐานองค์ความรู้ เพื่อสนับสนุนการเติบโตของวิสาหกิจดิจิทัลเริ่มต้น_x000D_\nการพัฒนาเครือข่ายระหว่างผู้ประกอบการวิสาหกิจดิจิทัลเริ่มต้น นักลงทุน หน่วยงานภาครัฐ หน่วยงานภาคเอกชน เพื่อให้เกิดการจับคู่ทางธุรกิจ ขยายโอกาสทางด้านการตลาด และขยายโอกาสในการเข้าถึงแหล่งทุนให้แก่วิสาหกิจดิจิทัลเริ่มต้น_x000D_\nส่งเสริมการขยายธุรกิจของวิสาหกิจดิจิทัลเริ่มต้นออกสู่ตลาดต่างประเทศ และสร้างความรับรู้เกี่ยวกับวิสาหกิจดิจิทัลเริ่มต้นไทยในเวทีนานาชาติ_x000D_\nศึกษาและเสนอแนะแนวทางแก้ไขและปรับปรุงกฎระเบียบเพื่อรองรับการเติบโตของวิสาหกิจดิจิทัลเริ่มต้นอย่างมีประสิทธิภาพ_x000D_\nส่งเสริมให้วิสาหกิจดิจิทัลเริ่มต้นสามารถเข้าถึงบริการภาครัฐ และตลาดภาครัฐ_x000D_\nส่งเสริมให้วิสาหกิจดิจิทัลเริ่มต้น มีบทบาทสำคัญในการขับเคลื่อนการเปลี่ยนแปลงทางเทคโนโลยีดิจิทัล (Digital transformation)_x000D_\nสนับสนุนการพัฒนากำลังคน เพื่อเป็นฐานในการพัฒนาวิสาหกิจดิจิทัลเริ่มต้นให้เติบโตอย่างมีศักยภาพ_x000D_\nดำเนินการร่วมกับเครือข่ายหน่วยงานทั้งในและต่างประเทศ เพื่อส่งเสริมบทบาทของประเทศไทยในการเป็นศูนย์กลางการพัฒนาวิสาหกิจดิจิทัลเริ่มต้นของภูมิภาค'},
#  {'name': 'promotion-and-support-for-the-development-of-modern-agriculture-department',
#   'title': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาการเกษตรสมัยใหม่',
#   'description': None},
#  {'name': 'industrial-and-business-development-department',
#   'title': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาอุตสาหกรรมและธุรกิจ',
#   'description': None},
#  {'name': 'dqs',
#   'title': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาคุณภาพชีวิตและความมั่นคง',
#   'description': None},
#  {'name': 'gbdi',
#   'title': 'สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใหญ่ภาครัฐ (GBDi)',
#   'description': 'สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใหญ่ภาครัฐ (GBDi) เป็นหน่วยงานภายใน ภายใต้สำนักงานส่งเสริมเศรษฐกิจดิจิทัล (depa) จัดตั้งขึ้นเพื่อตอบสนองการดำเนินงานตามแนวทางการใช้ประโยชน์จากข้อมูลขนาดใหญ่ (Big Data) และรองรับการให้บริการด้านการพัฒนาบุคลากรและการวิเคราะห์ข้อมูลขนาดใหญ่ (Big Data Analytics) ของภาครัฐ ตามยุทธศาสตร์ชาติยุทธศาสตร์ที่ 6 ด้านการปรับสมดุลและการพัฒนาระบบบริหารจัดการภาครัฐ_x000D_\n     ที่กำหนดให้มีระบบการบริหารจัดการข้อมูลที่มีความเชื่อมโยงระหว่างหน่วยงาน และแหล่งข้อมูลต่าง ๆ ไปสู่การวิเคราะห์การจัดการข้อมูลขนาดใหญ่ โดยมีวัตถุประสงค์เพื่อส่งเสริมให้เกิดวัฒนธรรมการวิเคราะห์และใช้ประโยชน์ข้อมูลขนาดใหญ่เพื่อประกอบการตัดสินใจ (Data-Driven Decision) สกัดข้อมูลเชิงลึกในการดำเนินงาน (Insight to Operation) และช่วยเหลือให้หน่วยงานภาครัฐสามารถให้บริการประชาชนได้อย่างเป็นรูปธรรม'}]

# %%
for org in org_master_dict:
    try:
        result = ckan_create_organization(org, CKAN_URL, API_KEY)
        print(result)
    except:
        pass
# Out:
# ----- org: corporate-strategy-department created
# {'display_name': 'ฝ่ายกลยุทธ์องค์กร', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.143158', 'name': 'corporate-strategy-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายกลยุทธ์องค์กร', 'num_followers': 0, 'id': 'f77c02fe-d303-4c49-91e1-5abc5cd862a4', 'tags': [], 'approval_status': 'approved'}
# ----- org: office-administration-department created
# {'display_name': 'ฝ่ายอำนวยการสำนักงาน', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.252116', 'name': 'office-administration-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายอำนวยการสำนักงาน', 'num_followers': 0, 'id': '617f3c46-e60b-46e7-a6f8-0f2eed31b7df', 'tags': [], 'approval_status': 'approved'}
# ----- org: policy-and-strategy-department created
# {'display_name': 'ฝ่ายนโยบายและยุทศาสตร์', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.339533', 'name': 'policy-and-strategy-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายนโยบายและยุทศาสตร์', 'num_followers': 0, 'id': '6cb592fc-4fe7-4fe2-8985-862c2a6f73be', 'tags': [], 'approval_status': 'approved'}
# ----- org: smart-city-department created
# {'display_name': 'ฝ่ายส่งเสริมเมืองอัจฉริยะ', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.428953', 'name': 'smart-city-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายส่งเสริมเมืองอัจฉริยะ', 'num_followers': 0, 'id': '08703a4c-cf4a-4e4e-aee3-161f53cd8a35', 'tags': [], 'approval_status': 'approved'}
# ----- org: digital-industry-promotion-department created
# {'display_name': 'ฝ่ายส่งเสริมอุตสาหกรรมดิจิทัล', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.516767', 'name': 'digital-industry-promotion-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายส่งเสริมอุตสาหกรรมดิจิทัล', 'num_followers': 0, 'id': '73013d5b-c51a-490b-a370-23f6a1c33823', 'tags': [], 'approval_status': 'approved'}
# ----- org: finanfe-and-central-administration-department created
# {'display_name': 'ฝ่ายบริหารการคลังและบริหารกลาง', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.608334', 'name': 'finanfe-and-central-administration-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายบริหารการคลังและบริหารกลาง', 'num_followers': 0, 'id': '055c2eb7-4a28-426f-9100-09e55a9b0146', 'tags': [], 'approval_status': 'approved'}
# ----- org: iot-institute created
# {'display_name': 'สถาบันไอโอทีและนวัตกรรมดิจิทัล', 'description': 'เป็นองค์กรหลักในการขับเคลื่อนการพัฒนาเทคโนโลยี นวัตกรรม และอุตสาหกรรมดิจิทัล เพื่อมุ่งสู่การเป็น “ศูนย์กลางด้านการออกแบบและพัฒนาเทคโนโลยีและนวัตกรรมดิจิทัลขั้นสูงแห่งภูมิภาคอาเซียน (ASEAN Digital Hub)”', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.703592', 'name': 'iot-institute', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'สถาบันไอโอทีและนวัตกรรมดิจิทัล', 'num_followers': 0, 'id': '0d554ca3-b610-49f2-bf28-43530273ab17', 'tags': [], 'approval_status': 'approved'}
# ----- org: dmd created
# {'display_name': 'ฝ่ายสงเสริมแพลตฟอร์มและบริการดิจิทัล', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.804877', 'name': 'dmd', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายสงเสริมแพลตฟอร์มและบริการดิจิทัล', 'num_followers': 0, 'id': '709f8c3b-3e6d-4a95-bd9c-3da640e2b914', 'tags': [], 'approval_status': 'approved'}
# ----- org: organization-and-human-resources-management-department created
# {'display_name': 'ฝ่ายบริหารทรัพยากรองค์กรและบุคคล', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:21.898718', 'name': 'organization-and-human-resources-management-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายบริหารทรัพยากรองค์กรและบุคคล', 'num_followers': 0, 'id': 'b425a35f-8227-4b17-a870-00b7e7117a4b', 'tags': [], 'approval_status': 'approved'}
# ----- org: digital-platform-and-service-promotion-department created
# {'display_name': 'ฝ่ายสงเสริมแพลตฟอร์มและบริการดิจิทัล', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:22.005985', 'name': 'digital-platform-and-service-promotion-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายสงเสริมแพลตฟอร์มและบริการดิจิทัล', 'num_followers': 0, 'id': '61e58eb3-5bb6-45cd-943e-c07dff1fd6c3', 'tags': [], 'approval_status': 'approved'}
# ----- org: startup-institute created
# {'display_name': 'สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น', 'description': 'สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น (Digital Startup Institute) เป็นสถาบันมุ่งเน้นความเป็นเลิศด้านการส่งเสริมวิสาหกิจเริ่มต้นครบวงจรภายใต้กำกับการดูแลของสำนักงานส่งเสริมเศรษฐกิจดิจิทัล ที่จัดตั้งขึ้นโดยมีวัตถุประสงค์เพื่อส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น (Digital Startups) ให้เป็นตัวจักรสำคัญในการพัฒนาและขับเคลื่อนประเทศสู่เศรษฐกิจดิจิทัล (Digital Economy) และเศรษฐกิจฐานผู้ประกอบการ (Entrepreneurial Economy) สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้นมุ่งเน้นการพัฒนาระบบนิเวศ (Ecosystem) ที่เหมาะสม เพื่อให้วิสาหกิจดิจิทัลเริ่มต้น สามารถเติบโตได้อย่างรวดเร็วและสามารถสร้างโอกาสทั้งในตลาดในประเทศและตลาดโลก ภารกิจที่สำคัญของสถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น ประกอบด้วย_x000D_\n_x000D_\nการพัฒนามาตรการส่งเสริมและสนับสนุน สิ่งอำนวยความสะดวก โครงสร้างพื้นฐาน และฐานองค์ความรู้ เพื่อสนับสนุนการเติบโตของวิสาหกิจดิจิทัลเริ่มต้น_x000D_\nการพัฒนาเครือข่ายระหว่างผู้ประกอบการวิสาหกิจดิจิทัลเริ่มต้น นักลงทุน หน่วยงานภาครัฐ หน่วยงานภาคเอกชน เพื่อให้เกิดการจับคู่ทางธุรกิจ ขยายโอกาสทางด้านการตลาด และขยายโอกาสในการเข้าถึงแหล่งทุนให้แก่วิสาหกิจดิจิทัลเริ่มต้น_x000D_\nส่งเสริมการขยายธุรกิจของวิสาหกิจดิจิทัลเริ่มต้นออกสู่ตลาดต่างประเทศ และสร้างความรับรู้เกี่ยวกับวิสาหกิจดิจิทัลเริ่มต้นไทยในเวทีนานาชาติ_x000D_\nศึกษาและเสนอแนะแนวทางแก้ไขและปรับปรุงกฎระเบียบเพื่อรองรับการเติบโตของวิสาหกิจดิจิทัลเริ่มต้นอย่างมีประสิทธิภาพ_x000D_\nส่งเสริมให้วิสาหกิจดิจิทัลเริ่มต้นสามารถเข้าถึงบริการภาครัฐ และตลาดภาครัฐ_x000D_\nส่งเสริมให้วิสาหกิจดิจิทัลเริ่มต้น มีบทบาทสำคัญในการขับเคลื่อนการเปลี่ยนแปลงทางเทคโนโลยีดิจิทัล (Digital transformation)_x000D_\nสนับสนุนการพัฒนากำลังคน เพื่อเป็นฐานในการพัฒนาวิสาหกิจดิจิทัลเริ่มต้นให้เติบโตอย่างมีศักยภาพ_x000D_\nดำเนินการร่วมกับเครือข่ายหน่วยงานทั้งในและต่างประเทศ เพื่อส่งเสริมบทบาทของประเทศไทยในการเป็นศูนย์กลางการพัฒนาวิสาหกิจดิจิทัลเริ่มต้นของภูมิภาค', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:22.098496', 'name': 'startup-institute', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'สถาบันส่งเสริมวิสาหกิจดิจิทัลเริ่มต้น', 'num_followers': 0, 'id': '20bbf57d-2d47-49f3-aaa9-a98b166815da', 'tags': [], 'approval_status': 'approved'}
# ----- org: promotion-and-support-for-the-development-of-modern-agriculture-department created
# {'display_name': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาการเกษตรสมัยใหม่', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:22.194111', 'name': 'promotion-and-support-for-the-development-of-modern-agriculture-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาการเกษตรสมัยใหม่', 'num_followers': 0, 'id': '500eb5ff-e341-47b7-b113-7c04d23e3043', 'tags': [], 'approval_status': 'approved'}
# ----- org: industrial-and-business-development-department created
# {'display_name': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาอุตสาหกรรมและธุรกิจ', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:22.291783', 'name': 'industrial-and-business-development-department', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาอุตสาหกรรมและธุรกิจ', 'num_followers': 0, 'id': 'e12a6bf3-42bf-4abd-94e8-97357dac67db', 'tags': [], 'approval_status': 'approved'}
# ----- org: dqs created
# {'display_name': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาคุณภาพชีวิตและความมั่นคง', 'description': '', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:22.387635', 'name': 'dqs', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'ฝ่ายส่งเสริมและสนับสนุนการพัฒนาคุณภาพชีวิตและความมั่นคง', 'num_followers': 0, 'id': 'af643cf1-ebbd-440f-b935-31a3cc9b8312', 'tags': [], 'approval_status': 'approved'}
# ----- org: gbdi created
# {'display_name': 'สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใหญ่ภาครัฐ (GBDi)', 'description': 'สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใหญ่ภาครัฐ (GBDi) เป็นหน่วยงานภายใน ภายใต้สำนักงานส่งเสริมเศรษฐกิจดิจิทัล (depa) จัดตั้งขึ้นเพื่อตอบสนองการดำเนินงานตามแนวทางการใช้ประโยชน์จากข้อมูลขนาดใหญ่ (Big Data) และรองรับการให้บริการด้านการพัฒนาบุคลากรและการวิเคราะห์ข้อมูลขนาดใหญ่ (Big Data Analytics) ของภาครัฐ ตามยุทธศาสตร์ชาติยุทธศาสตร์ที่ 6 ด้านการปรับสมดุลและการพัฒนาระบบบริหารจัดการภาครัฐ_x000D_\n     ที่กำหนดให้มีระบบการบริหารจัดการข้อมูลที่มีความเชื่อมโยงระหว่างหน่วยงาน และแหล่งข้อมูลต่าง ๆ ไปสู่การวิเคราะห์การจัดการข้อมูลขนาดใหญ่ โดยมีวัตถุประสงค์เพื่อส่งเสริมให้เกิดวัฒนธรรมการวิเคราะห์และใช้ประโยชน์ข้อมูลขนาดใหญ่เพื่อประกอบการตัดสินใจ (Data-Driven Decision) สกัดข้อมูลเชิงลึกในการดำเนินงาน (Insight to Operation) และช่วยเหลือให้หน่วยงานภาครัฐสามารถให้บริการประชาชนได้อย่างเป็นรูปธรรม', 'image_display_url': '', 'package_count': 0, 'created': '2023-07-25T15:40:22.476649', 'name': 'gbdi', 'is_organization': True, 'state': 'active', 'extras': [], 'image_url': '', 'groups': [], 'type': 'organization', 'title': 'สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใหญ่ภาครัฐ (GBDi)', 'num_followers': 0, 'id': '4e35c551-2d15-404f-ba8b-b29236ab0b3a', 'tags': [], 'approval_status': 'approved'}

# %% [markdown]
# ## Create user accounts:

# %%
df_user = pd.read_excel("user_org_role.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df_user
# Out:
#        ชื่อ           สกุล                   email  \
# 0  Kanyawee  Pornsawangdee  kanyawee.po@depa.or.th
# 1  Kanyawee  Pornsawangdee  kanyawee.po@depa.or.th
# 2     Name1       Surname1     name1.su@depa.pr.th
# 3     Name2       Surname2     name2.su@depa.pr.th
# 4     Name3       Surname3     name3.su@depa.pr.th
# 5     Name4       Surname4     name4.su@depa.pr.th
# 6     Name5       Surname5     name5.su@depa.pr.th
# 7     Name6       Surname6     name6.su@depa.pr.th
#
#                                             หน่วยงาน    role
# 0  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  member
# 1  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  editor
# 2                                  ฝ่ายกลยุทธ์องค์กร  member
# 3                                  ฝ่ายกลยุทธ์องค์กร  member
# 4                                  ฝ่ายกลยุทธ์องค์กร  member
# 5                                  ฝ่ายกลยุทธ์องค์กร  member
# 6                                  ฝ่ายกลยุทธ์องค์กร  member
# 7                                  ฝ่ายกลยุทธ์องค์กร  member

# %%
df_user_org = pd.merge(df_user, df_org[["org_id","org_name"]], left_on="หน่วยงาน", right_on="org_name", how='left')
df_user_org
# Out:
#        ชื่อ           สกุล                   email  \
# 0  Kanyawee  Pornsawangdee  kanyawee.po@depa.or.th
# 1  Kanyawee  Pornsawangdee  kanyawee.po@depa.or.th
# 2     Name1       Surname1     name1.su@depa.pr.th
# 3     Name2       Surname2     name2.su@depa.pr.th
# 4     Name3       Surname3     name3.su@depa.pr.th
# 5     Name4       Surname4     name4.su@depa.pr.th
# 6     Name5       Surname5     name5.su@depa.pr.th
# 7     Name6       Surname6     name6.su@depa.pr.th
#
#                                             หน่วยงาน    role  \
# 0  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  member
# 1  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  editor
# 2                                  ฝ่ายกลยุทธ์องค์กร  member
# 3                                  ฝ่ายกลยุทธ์องค์กร  member
# 4                                  ฝ่ายกลยุทธ์องค์กร  member
# 5                                  ฝ่ายกลยุทธ์องค์กร  member
# 6                                  ฝ่ายกลยุทธ์องค์กร  member
# 7                                  ฝ่ายกลยุทธ์องค์กร  member
#
#                           org_id  \
# 0                           gbdi
# 1                           gbdi
# 2  corporate-strategy-department
# 3  corporate-strategy-department
# 4  corporate-strategy-department
# 5  corporate-strategy-department
# 6  corporate-strategy-department
# 7  corporate-strategy-department
#
#                                             org_name
# 0  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...
# 1  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...
# 2                                  ฝ่ายกลยุทธ์องค์กร
# 3                                  ฝ่ายกลยุทธ์องค์กร
# 4                                  ฝ่ายกลยุทธ์องค์กร
# 5                                  ฝ่ายกลยุทธ์องค์กร
# 6                                  ฝ่ายกลยุทธ์องค์กร
# 7                                  ฝ่ายกลยุทธ์องค์กร

# %%
df_user_org["id"] = df_user_org["email"].str.split("@").str[0].str.replace('.', '_')
df_user_org["name"] = df_user_org["email"].str.split("@").str[0].str.replace('.', '_')
# Out:
# <ipython-input-20-c86a9a09565d>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_user_org["id"] = df_user_org["email"].str.split("@").str[0].str.replace('.', '_')
# <ipython-input-20-c86a9a09565d>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_user_org["name"] = df_user_org["email"].str.split("@").str[0].str.replace('.', '_')

# %%
df_user_org
# Out:
#        ชื่อ           สกุล                   email  \
# 0  Kanyawee  Pornsawangdee  kanyawee.po@depa.or.th
# 1  Kanyawee  Pornsawangdee  kanyawee.po@depa.or.th
# 2     Name1       Surname1     name1.su@depa.pr.th
# 3     Name2       Surname2     name2.su@depa.pr.th
# 4     Name3       Surname3     name3.su@depa.pr.th
# 5     Name4       Surname4     name4.su@depa.pr.th
# 6     Name5       Surname5     name5.su@depa.pr.th
# 7     Name6       Surname6     name6.su@depa.pr.th
#
#                                             หน่วยงาน    role  \
# 0  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  member
# 1  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  editor
# 2                                  ฝ่ายกลยุทธ์องค์กร  member
# 3                                  ฝ่ายกลยุทธ์องค์กร  member
# 4                                  ฝ่ายกลยุทธ์องค์กร  member
# 5                                  ฝ่ายกลยุทธ์องค์กร  member
# 6                                  ฝ่ายกลยุทธ์องค์กร  member
# 7                                  ฝ่ายกลยุทธ์องค์กร  member
#
#                           org_id  \
# 0                           gbdi
# 1                           gbdi
# 2  corporate-strategy-department
# 3  corporate-strategy-department
# 4  corporate-strategy-department
# 5  corporate-strategy-department
# 6  corporate-strategy-department
# 7  corporate-strategy-department
#
#                                             org_name           id         name
# 0  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  kanyawee_po  kanyawee_po
# 1  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  kanyawee_po  kanyawee_po
# 2                                  ฝ่ายกลยุทธ์องค์กร     name1_su     name1_su
# 3                                  ฝ่ายกลยุทธ์องค์กร     name2_su     name2_su
# 4                                  ฝ่ายกลยุทธ์องค์กร     name3_su     name3_su
# 5                                  ฝ่ายกลยุทธ์องค์กร     name4_su     name4_su
# 6                                  ฝ่ายกลยุทธ์องค์กร     name5_su     name5_su
# 7                                  ฝ่ายกลยุทธ์องค์กร     name6_su     name6_su

# %%
df_user_org["fullname"] = df_user_org["ชื่อ"] + ' ' + df_user_org["สกุล"]
df_user_org["password"] = "ckan1234"
df_user_org["about"] = ""
df_user_org["state"] = "active"

# %%
df_user_org
# Out:
#        ชื่อ           สกุล                   email  \
# 0  Kanyawee  Pornsawangdee  kanyawee.po@depa.or.th
# 1  Kanyawee  Pornsawangdee  kanyawee.po@depa.or.th
# 2     Name1       Surname1     name1.su@depa.pr.th
# 3     Name2       Surname2     name2.su@depa.pr.th
# 4     Name3       Surname3     name3.su@depa.pr.th
# 5     Name4       Surname4     name4.su@depa.pr.th
# 6     Name5       Surname5     name5.su@depa.pr.th
# 7     Name6       Surname6     name6.su@depa.pr.th
#
#                                             หน่วยงาน    role  \
# 0  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  member
# 1  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  editor
# 2                                  ฝ่ายกลยุทธ์องค์กร  member
# 3                                  ฝ่ายกลยุทธ์องค์กร  member
# 4                                  ฝ่ายกลยุทธ์องค์กร  member
# 5                                  ฝ่ายกลยุทธ์องค์กร  member
# 6                                  ฝ่ายกลยุทธ์องค์กร  member
# 7                                  ฝ่ายกลยุทธ์องค์กร  member
#
#                           org_id  \
# 0                           gbdi
# 1                           gbdi
# 2  corporate-strategy-department
# 3  corporate-strategy-department
# 4  corporate-strategy-department
# 5  corporate-strategy-department
# 6  corporate-strategy-department
# 7  corporate-strategy-department
#
#                                             org_name           id  \
# 0  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  kanyawee_po
# 1  สถาบันส่งเสริมการวิเคราะห์และบริหารข้อมูลขนาดใ...  kanyawee_po
# 2                                  ฝ่ายกลยุทธ์องค์กร     name1_su
# 3                                  ฝ่ายกลยุทธ์องค์กร     name2_su
# 4                                  ฝ่ายกลยุทธ์องค์กร     name3_su
# 5                                  ฝ่ายกลยุทธ์องค์กร     name4_su
# 6                                  ฝ่ายกลยุทธ์องค์กร     name5_su
# 7                                  ฝ่ายกลยุทธ์องค์กร     name6_su
#
#           name                fullname  password about   state
# 0  kanyawee_po  Kanyawee Pornsawangdee  ckan1234        active
# 1  kanyawee_po  Kanyawee Pornsawangdee  ckan1234        active
# 2     name1_su          Name1 Surname1  ckan1234        active
# 3     name2_su          Name2 Surname2  ckan1234        active
# 4     name3_su          Name3 Surname3  ckan1234        active
# 5     name4_su          Name4 Surname4  ckan1234        active
# 6     name5_su          Name5 Surname5  ckan1234        active
# 7     name6_su          Name6 Surname6  ckan1234        active

# %%
df_user_org_master = df_user_org[["id","name","email",'password','fullname','about','state']]
df_user_org_master
# Out:
#             id         name                   email  password  \
# 0  kanyawee_po  kanyawee_po  kanyawee.po@depa.or.th  ckan1234
# 1  kanyawee_po  kanyawee_po  kanyawee.po@depa.or.th  ckan1234
# 2     name1_su     name1_su     name1.su@depa.pr.th  ckan1234
# 3     name2_su     name2_su     name2.su@depa.pr.th  ckan1234
# 4     name3_su     name3_su     name3.su@depa.pr.th  ckan1234
# 5     name4_su     name4_su     name4.su@depa.pr.th  ckan1234
# 6     name5_su     name5_su     name5.su@depa.pr.th  ckan1234
# 7     name6_su     name6_su     name6.su@depa.pr.th  ckan1234
#
#                  fullname about   state
# 0  Kanyawee Pornsawangdee        active
# 1  Kanyawee Pornsawangdee        active
# 2          Name1 Surname1        active
# 3          Name2 Surname2        active
# 4          Name3 Surname3        active
# 5          Name4 Surname4        active
# 6          Name5 Surname5        active
# 7          Name6 Surname6        active

# %%
df_user_org_master.to_json('df_user_org_master.json', force_ascii=False, orient='records')

# %%
with open('df_user_org_master.json', encoding="utf8") as readfile:
    user_org_master_dict =  json.load(readfile)

# %%
user_org_master_dict
# Out:
# [{'id': 'kanyawee_po',
#   'name': 'kanyawee_po',
#   'email': 'kanyawee.po@depa.or.th',
#   'password': 'ckan1234',
#   'fullname': 'Kanyawee Pornsawangdee',
#   'about': '',
#   'state': 'active'},
#  {'id': 'kanyawee_po',
#   'name': 'kanyawee_po',
#   'email': 'kanyawee.po@depa.or.th',
#   'password': 'ckan1234',
#   'fullname': 'Kanyawee Pornsawangdee',
#   'about': '',
#   'state': 'active'},
#  {'id': 'name1_su',
#   'name': 'name1_su',
#   'email': 'name1.su@depa.pr.th',
#   'password': 'ckan1234',
#   'fullname': 'Name1 Surname1',
#   'about': '',
#   'state': 'active'},
#  {'id': 'name2_su',
#   'name': 'name2_su',
#   'email': 'name2.su@depa.pr.th',
#   'password': 'ckan1234',
#   'fullname': 'Name2 Surname2',
#   'about': '',
#   'state': 'active'},
#  {'id': 'name3_su',
#   'name': 'name3_su',
#   'email': 'name3.su@depa.pr.th',
#   'password': 'ckan1234',
#   'fullname': 'Name3 Surname3',
#   'about': '',
#   'state': 'active'},
#  {'id': 'name4_su',
#   'name': 'name4_su',
#   'email': 'name4.su@depa.pr.th',
#   'password': 'ckan1234',
#   'fullname': 'Name4 Surname4',
#   'about': '',
#   'state': 'active'},
#  {'id': 'name5_su',
#   'name': 'name5_su',
#   'email': 'name5.su@depa.pr.th',
#   'password': 'ckan1234',
#   'fullname': 'Name5 Surname5',
#   'about': '',
#   'state': 'active'},
#  {'id': 'name6_su',
#   'name': 'name6_su',
#   'email': 'name6.su@depa.pr.th',
#   'password': 'ckan1234',
#   'fullname': 'Name6 Surname6',
#   'about': '',
#   'state': 'active'}]

# %%
for user in user_org_master_dict:
    try:
        _ = ckan_create_user(user, CKAN_URL, API_KEY)
    except:
        _ = ckan_update_user(user, CKAN_URL, API_KEY)
# Out:
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_create", "success": true, "result": {"email_hash": "8c6a87f90707b6f9563baf3af9fbc800", "about": "", "apikey": null, "display_name": "Kanyawee Pornsawangdee", "name": "kanyawee_po", "created": "2023-07-25T15:43:46.091822", "image_display_url": null, "id": "kanyawee_po", "sysadmin": false, "activity_streams_email_notifications": false, "state": "active", "image_url": null, "fullname": "Kanyawee Pornsawangdee", "email": "kanyawee.po@depa.or.th", "number_created_packages": 0}}
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_create", "success": false, "error": {"name": ["\u0e0a\u0e37\u0e48\u0e2d\u0e25\u0e4a\u0e2d\u0e01\u0e2d\u0e34\u0e19\u0e19\u0e35\u0e49\u0e44\u0e21\u0e48\u0e27\u0e48\u0e32\u0e07"], "__type": "Validation Error"}}
# {'id': 'kanyawee_po', 'name': 'kanyawee_po', 'email': 'kanyawee.po@depa.or.th', 'password': 'ckan1234', 'fullname': 'Kanyawee Pornsawangdee', 'about': '', 'state': 'active'}
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_update", "success": true, "result": {"email_hash": "8c6a87f90707b6f9563baf3af9fbc800", "about": "", "apikey": null, "display_name": "Kanyawee Pornsawangdee", "name": "kanyawee_po", "created": "2023-07-25T15:43:46.091822", "image_display_url": null, "id": "kanyawee_po", "sysadmin": false, "activity_streams_email_notifications": false, "state": "active", "image_url": null, "fullname": "Kanyawee Pornsawangdee", "email": "kanyawee.po@depa.or.th", "number_created_packages": 0}}
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_create", "success": true, "result": {"email_hash": "dcda4cdc4c8e096326e20042619a6ed4", "about": "", "apikey": null, "display_name": "Name1 Surname1", "name": "name1_su", "created": "2023-07-25T15:43:46.475020", "image_display_url": null, "id": "name1_su", "sysadmin": false, "activity_streams_email_notifications": false, "state": "active", "image_url": null, "fullname": "Name1 Surname1", "email": "name1.su@depa.pr.th", "number_created_packages": 0}}
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_create", "success": true, "result": {"email_hash": "49f9c4963fd9a27c6876eaab0fd3e88e", "about": "", "apikey": null, "display_name": "Name2 Surname2", "name": "name2_su", "created": "2023-07-25T15:43:46.642463", "image_display_url": null, "id": "name2_su", "sysadmin": false, "activity_streams_email_notifications": false, "state": "active", "image_url": null, "fullname": "Name2 Surname2", "email": "name2.su@depa.pr.th", "number_created_packages": 0}}
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_create", "success": true, "result": {"email_hash": "de8ba170f6e154aa2d07239557dd5b1e", "about": "", "apikey": null, "display_name": "Name3 Surname3", "name": "name3_su", "created": "2023-07-25T15:43:46.809787", "image_display_url": null, "id": "name3_su", "sysadmin": false, "activity_streams_email_notifications": false, "state": "active", "image_url": null, "fullname": "Name3 Surname3", "email": "name3.su@depa.pr.th", "number_created_packages": 0}}
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_create", "success": true, "result": {"email_hash": "dab92626c997084c3a3ce8a6e4bd3086", "about": "", "apikey": null, "display_name": "Name4 Surname4", "name": "name4_su", "created": "2023-07-25T15:43:46.977267", "image_display_url": null, "id": "name4_su", "sysadmin": false, "activity_streams_email_notifications": false, "state": "active", "image_url": null, "fullname": "Name4 Surname4", "email": "name4.su@depa.pr.th", "number_created_packages": 0}}
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_create", "success": true, "result": {"email_hash": "0d88f28777b17993b1fc9fa1aa5d61d7", "about": "", "apikey": null, "display_name": "Name5 Surname5", "name": "name5_su", "created": "2023-07-25T15:43:47.145765", "image_display_url": null, "id": "name5_su", "sysadmin": false, "activity_streams_email_notifications": false, "state": "active", "image_url": null, "fullname": "Name5 Surname5", "email": "name5.su@depa.pr.th", "number_created_packages": 0}}
# {"help": "http://35.229.135.112/api/3/action/help_show?name=user_create", "success": true, "result": {"email_hash": "7fff8a20cb33d8eec0e003bbec2ae28d", "about": "", "apikey": null, "display_name": "Name6 Surname6", "name": "name6_su", "created": "2023-07-25T15:43:47.315717", "image_display_url": null, "id": "name6_su", "sysadmin": false, "activity_streams_email_notifications": false, "state": "active", "image_url": null, "fullname": "Name6 Surname6", "email": "name6.su@depa.pr.th", "number_created_packages": 0}}

# %% [markdown]
# ## Delete user accounts:

# %%
# df_user_org_master[['id']].to_json('df_user_id_list.json', force_ascii=False, orient='records')

# %%
# with open('df_user_id_list.json', encoding="utf8") as readfile:
#     user_id_list_dict =  json.load(readfile)

# %%
# for user_id in user_id_list_dict:
#     try:
#         _ = ckan_delete_user(user_id, CKAN_URL, API_KEY)
#     except:
#         pass

# %% [markdown]
# ## Assign role and organization:
